# %% [markdown]
# import cv2
# import numpy as np
# from matplotlib import pyplot as plt
# plt.rcParams['figure.figsize'] = [15, 10]

# %%
import cv2
import numpy as np

# Завантаження зображення
img = cv2.imread('001.jpg')  # Оновіть з шляхом до вашого зображення

# Порогова фільтрація для знаходження білого кольору
white_threshold = 230  # Значення порогу для кожного каналу (можна налаштувати)
white_mask = (img[:,:,0] > white_threshold) & (img[:,:,1] > white_threshold) & (img[:,:,2] > white_threshold)

# Застосування маски до оригінального зображення
white_pixels = img.copy()
white_pixels[~white_mask] = [0, 0, 0]  # Залишити тільки білі пікселі, решту зробити чорними

# Відображення оригінального зображення та виділення білих пікселів
cv2.imshow('Original Image', img)
cv2.imshow('White Pixels', white_pixels)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Out:
# [ WARN:0@412.792] global /croot/opencv-suite_1691620365762/work/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('001.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@412.793] global /croot/opencv-suite_1691620365762/work/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('002.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 img = cv2.imread('002.jpg')
#       5 # Plot it
# ----> 6 plt.imshow(img)
#
# File /opt/conda/envs/anaconda-ai-2023-11/lib/python3.10/site-packages/matplotlib/pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3325 @_copy_docstring_and_deprecators(Axes.imshow)
#    3326 def imshow(
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Load an image
img = cv2.imread('wb1.png')

# Check if the image is loaded successfully
if img is not None:
    # Convert it to RGB
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Plot it
    plt.imshow(img_rgb)
    plt.show()
else:
    print("Error: Image not found")
# Out:
# Error: Image not found
# [ WARN:0@929.710] global /croot/opencv-suite_1691620365762/work/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('wb1.png'): can't open/read file: check file path/integrity

# %%
import cv2
import matplotlib.pyplot as plt

# Load an image
img = cv2.imread('001.jpg')

# Check if the image is loaded successfully
if img is not None:
    # Convert it to RGB
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Plot it
    plt.imshow(img_rgb)
    plt.show()
else:
    print("Error: Image not found")

# %%
import cv2
import matplotlib.pyplot as plt

# Load an image
img = cv2.imread('Users/mac/Documents/R_D/COM_VIS/Les1/001.jpg')

# Check if the image is loaded successfully
if img is not None:
    # Convert it to RGB
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Plot it
    plt.imshow(img_rgb)
    plt.show()
else:
    print("Error: Image not found")
# Out:
# Error: Image not found
# [ WARN:0@2003.639] global /croot/opencv-suite_1691620365762/work/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('Users/mac/Documents/R_D/COM_VIS/Les1/001.jpg'): can't open/read file: check file path/integrity

# %%
img = cv2.imread('001.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
img_path = '001.jpg'  # Update with the actual path to your image
img = cv2.imread(img_path)

# Specify the coordinates of the white patch
row, col = 552, 1000

# Extract the color values of the white patch
white = img[row, col, :]

# Calculate scaling coefficients
coeffs = 255.0 / white

# Apply white balancing and generate a balanced image
balanced = np.zeros_like(img, dtype=np.float32)
for channel in range(3):
    balanced[..., channel] = img[..., channel] * coeffs[channel]

# Normalize the balanced image to the range [0, 1]
balanced = balanced / 255

# Clip values greater than 1 to preserve dynamic range
balanced[balanced > 1] = 1

# Display the original and balanced images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(balanced)
plt.title('White Patch Balanced Image')
plt.axis('off')

plt.show()

# %%
import cv2

# Завантаження зображення
img = cv2.imread('001.jpg')  # Оновіть з шляхом до вашого зображення

# Отримання форми зображення (висота, ширина, канали)
height, width, channels = img.shape

# Виведення кількості рядів і колонок
print(f"Кількість рядів: {height}")
print(f"Кількість колонок: {width}")
# Out:
# Кількість рядів: 960
# Кількість колонок: 1280

# %%
row, col = 550, 1000 
white = img[row, col, :]
coeffs = 255.0/white

# Apply white balancing and generate balanced image
balanced = np.zeros_like(img, dtype=np.float32)
for channel in range(3):
    balanced[..., channel] = img[..., channel] * coeffs[channel]

# White patching does not guarantee that the dynamic range is preserved, images must be clipped.
balanced = balanced/255
balanced[balanced > 1] = 1

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(balanced)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7f603aa94f40>)
