# %%
import cv2
import matplotlib.pyplot as plt

# Load an image
img = cv2.imread('001.jpg')

# Check if the image is loaded successfully
if img is not None:
    # Convert it to RGB
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Plot it
    plt.imshow(img_rgb)
    plt.show()
else:
    print("Error: Image not found")

# %%
img = cv2.imread('001.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
img_path = '001.jpg'  # Update with the actual path to your image
img = cv2.imread(img_path)

# Specify the coordinates of the white patch
row, col = 552, 1000

# Extract the color values of the white patch
white = img[row, col, :]

# Calculate scaling coefficients
coeffs = 255.0 / white

# Apply white balancing and generate a balanced image
balanced = np.zeros_like(img, dtype=np.float32)
for channel in range(3):
    balanced[..., channel] = img[..., channel] * coeffs[channel]

# Normalize the balanced image to the range [0, 1]
balanced = balanced / 255

# Clip values greater than 1 to preserve dynamic range
balanced[balanced > 1] = 1

# Display the original and balanced images
plt.figure(figsize=(10, 5))


plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(balanced)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7fe6338fef50>)

# %%
import cv2
import numpy as np

img = cv2.imread('112.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# average value for each color
mean_r = np.mean(img[:, :, 0])  # average value red
mean_g = np.mean(img[:, :, 1])  # average value green
mean_b = np.mean(img[:, :, 2])  # average value gray

# coefficients calculation
kr = 1
kg = mean_g / mean_r
kb = mean_b / mean_r

print("coefficients:")
print("kr:", kr)
print("kg:", kg)
print("kb:", kb)
# Out:
# coefficients:
# kr: 1
# kg: 1.026542171353432
# kb: 1.1208982209240947

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('112.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

mean_r = np.mean(img[:, :, 0])
mean_g = np.mean(img[:, :, 1])
mean_b = np.mean(img[:, :, 2])

kr = 1
kg = mean_g / mean_r
kb = mean_b / mean_r

balanced = img.copy()
balanced[:, :, 0] = img[:, :, 0] * kr
balanced[:, :, 1] = img[:, :, 1] * kg
balanced[:, :, 2] = img[:, :, 2] * kb

# original and balanced
plt.subplot(121), plt.imshow(img)
plt.title('Original Image')
plt.axis('off')

plt.subplot(122), plt.imshow(balanced)
plt.title('Balanced Image')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('505.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

max_r = np.max(img[:, :, 0])
max_g = np.max(img[:, :, 1])
max_b = np.max(img[:, :, 2])

# scale-by-max
scaling_factor = 0.005
balanced = img.copy()
balanced[:, :, 0] = img[:, :, 0] / (max_r * scaling_factor)
balanced[:, :, 1] = img[:, :, 1] / (max_g * scaling_factor)
balanced[:, :, 2] = img[:, :, 2] / (max_b * scaling_factor)


plt.subplot(121), plt.imshow(img)
plt.title('Original')
plt.axis('off')

plt.subplot(122), plt.imshow(balanced)
plt.title('Balanced')
plt.axis('off')

plt.show()
print("Max Red Value:", max_r)
print("Max Green Value:", max_g)
print("Max Blue Value:", max_b)
# Out:
# Max Red Value: 255
# Max Green Value: 255
# Max Blue Value: 255

# %%
plt.subplot(121), plt.imshow(img)
plt.title('Original')
plt.axis('off')

plt.subplot(122), plt.imshow(balanced)
plt.title('Balanced')
plt.axis('off')

plt.show()

plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.hist(balanced[:,:,0].ravel(), bins=256, color='red', alpha=0.5)
plt.title('Red Channel (Balanced)')
plt.xlabel('Intensity')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
img_path = '113.jpg'  # Update with the actual path to your image
img = cv2.imread(img_path)

# Specify the coordinates of the white patch
row, col = 400, 700

# Extract the color values of the white patch
white = img[row, col, :]

# Calculate scaling coefficients
coeffs = 255.0 / white

# Apply white balancing and generate a balanced image
balanced = np.zeros_like(img, dtype=np.float32)
for channel in range(3):
    balanced[..., channel] = img[..., channel] * coeffs[channel]

# Normalize the balanced image to the range [0, 1]
balanced = balanced / 255

# Clip values greater than 1 to preserve dynamic range
balanced[balanced > 1] = 1

# Display the original and balanced images
plt.figure(figsize=(10, 5))


plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(balanced)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7fde73cf27d0>)
